# %% [markdown]
# <a href="https://colab.research.google.com/github/Punambhatt/Machine-Learning/blob/main/Gradient_Descent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
np.random.seed(42)
X = np.linspace(0, 10, 50)
true_m, true_c = 2, 1
y = true_m * X + true_c + np.random.normal(0, 2, X.shape)

# %%
m, c = 0.0, 0.0
learning_rate = 0.01
iterations = 200

# %%
loss_history = []

# %%
for i in range(iterations):
    y_pred = m * X + c

    m_grad = (-2 / len(X)) * np.sum(X * (y - y_pred))
    c_grad = (-2 / len(X)) * np.sum(y - y_pred)

    m = m - learning_rate * m_grad
    c = c - learning_rate * c_grad

    loss = np.mean((y - y_pred) ** 2)
    loss_history.append(loss)

    if i % 10 == 0:
        print(f"Iteration {i}: Loss = {loss:.4f}, m = {m:.4f}, c = {c:.4f}")
# Out:
# Iteration 0: Loss = 3.3006, m = 1.8848, c = 1.1236
# Iteration 10: Loss = 3.3006, m = 1.8848, c = 1.1239
# Iteration 20: Loss = 3.3006, m = 1.8847, c = 1.1241
# Iteration 30: Loss = 3.3006, m = 1.8847, c = 1.1244
# Iteration 40: Loss = 3.3006, m = 1.8847, c = 1.1246
# Iteration 50: Loss = 3.3006, m = 1.8846, c = 1.1248
# Iteration 60: Loss = 3.3006, m = 1.8846, c = 1.1250
# Iteration 70: Loss = 3.3006, m = 1.8846, c = 1.1252
# Iteration 80: Loss = 3.3006, m = 1.8846, c = 1.1254
# Iteration 90: Loss = 3.3006, m = 1.8845, c = 1.1256
# Iteration 100: Loss = 3.3006, m = 1.8845, c = 1.1257
# Iteration 110: Loss = 3.3006, m = 1.8845, c = 1.1259
# Iteration 120: Loss = 3.3006, m = 1.8845, c = 1.1260
# Iteration 130: Loss = 3.3006, m = 1.8844, c = 1.1262
# Iteration 140: Loss = 3.3006, m = 1.8844, c = 1.1263
# Iteration 150: Loss = 3.3006, m = 1.8844, c = 1.1264
# Iteration 160: Loss = 3.3006, m = 1.8844, c = 1.1265
# Iteration 170: Loss = 3.3006, m = 1.8844, c = 1.1267
# Iteration 180: Loss = 3.3006, m = 1.8843, c = 1.1268
# Iteration 190: Loss = 3.3006, m = 1.8843, c = 1.1269
# Iteration 200: Loss = 3.3006, m = 1.8843, c = 1.1270
# Iteration 210: Loss = 3.3006, m = 1.8843, c = 1.1271
# Iteration 220: Loss = 3.3006, m = 1.8843, c = 1.1272
# Iteration 230: Loss = 3.3006, m = 1.8843, c = 1.1272
# Iteration 240: Loss = 3.3006, m = 1.8843, c = 1.1273
# Iteration 250: Loss = 3.3006, m = 1.8843, c = 1.1274
# Iteration 260: Loss = 3.3006, m = 1.8842, c = 1.1275
# Iteration 270: Loss = 3.3006, m = 1.8842, c = 1.1275
# Iteration 280: Loss = 3.3006, m = 1.8842, c = 1.1276
# Iteration 290: Loss = 3.3006, m = 1.8842, c = 1.1277
# Iteration 300: Loss = 3.3006, m = 1.8842, c = 1.1277
# Iteration 310: Loss = 3.3006, m = 1.8842, c = 1.1278
# Iteration 320: Loss = 3.3006, m = 1.8842, c = 1.1278
# Iteration 330: Loss = 3.3006, m = 1.8842, c = 1.1279
# Iteration 340: Loss = 3.3006, m = 1.8842, c = 1.1279
# Iteration 350: Loss = 3.3006, m = 1.8842, c = 1.1280
# Iteration 360: Loss = 3.3006, m = 1.8842, c = 1.1280
# Iteration 370: Loss = 3.3006, m = 1.8842, c = 1.1281
# Iteration 380: Loss = 3.3006, m = 1.8841, c = 1.1281
# Iteration 390: Loss = 3.3006, m = 1.8841, c = 1.1282
# Iteration 400: Loss = 3.3006, m = 1.8841, c = 1.1282
# Iteration 410: Loss = 3.3006, m = 1.8841, c = 1.1282
# Iteration 420: Loss = 3.3006, m = 1.8841, c = 1.1283
# Iteration 430: Loss = 3.3006, m = 1.8841, c = 1.1283
# Iteration 440: Loss = 3.3006, m = 1.8841, c = 1.1283
# Iteration 450: Loss = 3.3006, m = 1.8841, c = 1.1283
# Iteration 460: Loss = 3.3006, m = 1.8841, c = 1.1284
# Iteration 470: Loss = 3.3006, m = 1.8841, c = 1.1284
# Iteration 480: Loss = 3.3006, m = 1.8841, c = 1.1284
# Iteration 490: Loss = 3.3006, m = 1.8841, c = 1.1284
# Iteration 500: Loss = 3.3006, m = 1.8841, c = 1.1285
# Iteration 510: Loss = 3.3006, m = 1.8841, c = 1.1285
# Iteration 520: Loss = 3.3006, m = 1.8841, c = 1.1285
# Iteration 530: Loss = 3.3006, m = 1.8841, c = 1.1285
# Iteration 540: Loss = 3.3006, m = 1.8841, c = 1.1285
# Iteration 550: Loss = 3.3006, m = 1.8841, c = 1.1286
# Iteration 560: Loss = 3.3006, m = 1.8841, c = 1.1286
# Iteration 570: Loss = 3.3006, m = 1.8841, c = 1.1286
# Iteration 580: Loss = 3.3006, m = 1.8841, c = 1.1286
# Iteration 590: Loss = 3.3006, m = 1.8841, c = 1.1286
# Iteration 600: Loss = 3.3006, m = 1.8841, c = 1.1286
# Iteration 610: Loss = 3.3006, m = 1.8841, c = 1.1286
# Iteration 620: Loss = 3.3006, m = 1.8841, c = 1.1287
# Iteration 630: Loss = 3.3006, m = 1.8841, c = 1.1287
# Iteration 640: Loss = 3.3006, m = 1.8841, c = 1.1287
# Iteration 650: Loss = 3.3006, m = 1.8841, c = 1.1287
# Iteration 660: Loss = 3.3006, m = 1.8841, c = 1.1287
# Iteration 670: Loss = 3.3006, m = 1.8841, c = 1.1287
# Iteration 680: Loss = 3.3006, m = 1.8841, c = 1.1287
# Iteration 690: Loss = 3.3006, m = 1.8841, c = 1.1287
# Iteration 700: Loss = 3.3006, m = 1.8841, c = 1.1287
# Iteration 710: Loss = 3.3006, m = 1.8841, c = 1.1287
# Iteration 720: Loss = 3.3006, m = 1.8841, c = 1.1287
# Iteration 730: Loss = 3.3006, m = 1.8841, c = 1.1288
# Iteration 740: Loss = 3.3006, m = 1.8841, c = 1.1288
# Iteration 750: Loss = 3.3006, m = 1.8841, c = 1.1288
# Iteration 760: Loss = 3.3006, m = 1.8841, c = 1.1288
# Iteration 770: Loss = 3.3006, m = 1.8840, c = 1.1288
# Iteration 780: Loss = 3.3006, m = 1.8840, c = 1.1288
# Iteration 790: Loss = 3.3006, m = 1.8840, c = 1.1288
# Iteration 800: Loss = 3.3006, m = 1.8840, c = 1.1288
# Iteration 810: Loss = 3.3006, m = 1.8840, c = 1.1288
# Iteration 820: Loss = 3.3006, m = 1.8840, c = 1.1288
# Iteration 830: Loss = 3.3006, m = 1.8840, c = 1.1288
# Iteration 840: Loss = 3.3006, m = 1.8840, c = 1.1288
# Iteration 850: Loss = 3.3006, m = 1.8840, c = 1.1288
# Iteration 860: Loss = 3.3006, m = 1.8840, c = 1.1288
# Iteration 870: Loss = 3.3006, m = 1.8840, c = 1.1288
# Iteration 880: Loss = 3.3006, m = 1.8840, c = 1.1288
# Iteration 890: Loss = 3.3006, m = 1.8840, c = 1.1288
# Iteration 900: Loss = 3.3006, m = 1.8840, c = 1.1288
# Iteration 910: Loss = 3.3006, m = 1.8840, c = 1.1288
# Iteration 920: Loss = 3.3006, m = 1.8840, c = 1.1288
# Iteration 930: Loss = 3.3006, m = 1.8840, c = 1.1288
# Iteration 940: Loss = 3.3006, m = 1.8840, c = 1.1288
# Iteration 950: Loss = 3.3006, m = 1.8840, c = 1.1288
# Iteration 960: Loss = 3.3006, m = 1.8840, c = 1.1288
# Iteration 970: Loss = 3.3006, m = 1.8840, c = 1.1288
# Iteration 980: Loss = 3.3006, m = 1.8840, c = 1.1288
# Iteration 990: Loss = 3.3006, m = 1.8840, c = 1.1289

# %%
print(f"Final parameters: m = {m:.4f}, c = {c:.4f}")

plt.figure(figsize=(10, 6))
plt.scatter(X, y, label="Data Points", color="blue")
plt.plot(X, m * X + c, label=f"Fitted Line: y = {m:.2f}x + {c:.2f}", color="red")
plt.title("Gradient Descent: Line Fitting")
plt.xlabel("X")
plt.ylabel("y")
plt.legend()
plt.show()
# Out:
# Final parameters: m = 1.8848, c = 1.1236
